# %%
print("hello world")
# output will be 'Hello World'

print(3.14) # output: 3.14
print(2 + 3) # output: 5

print("hello world", "from Harjot") # output: hello world from Harjot
# Out:
# hello world
# 3.14
# 5
# hello world from Harjot

# %% [markdown]
# Python Character Set
# A Character set is a collection of characters, numbers, symbols that our language
# recognizes & we can use. Following are the common characters we’ll be frequently
# using in Python:
# 1. English letters - to ’ and to
# 2. Digits -0 to 9
# 3. Special symbols - +, -, *, /, %, etc.
# 4. Whitespaces & Escape characters - blank space ( ), tab space ( \t), newline ( \n)
# etc.
# 5. All ASCII & Unicode characters as part of data & literals
#
#
#
# A variable is like a container that stores data or values in our program. We can
# think of it as a labeled box where we can place something in, change it, or use it later.
# There are variables in Python:
# 1. Have names called identifiers.
# 2. Can store data of any type (numbers, text etc.)

# %%
name = "Harjot Singh"
age = 22
PI = 3.14
word = "arificial intelligence"
print ("value of PI =", PI)
# Out:
# value of PI = 3.14

# %% [markdown]
# Variable Naming(identifier) Rules
# 1. Name must start with a letter (a–z, A–Z) or underscore .
# 2. Can contain letters, numbers, or underscores after the first character.
# 3. Cannot use Python keywords (like if , for, class ) as variable names.

# %%
#Let’s look at some invalid variable names:

#2name = "Bob" # Starts with a number
#class = 10 # 'class' is a keywor

# %% [markdown]
# Important Note
# 1. Python is dynamically typed. So when creating variables we don't
# need to declare type explicitly.
# 2. Python is a case-sensitive i.e. variable age & Age are different.
# 3. Indentation in Python is important & the general standard is 4
# spaces per indentation level.
# 4. Keywords are reserved words in Python & their meanings are
# predefined by the language.
# Examples- if , for, class , while , else , in , def etc.

# %% [markdown]
# A data type defines the kind of value a variable can hold. Python has several
# built-in data types.
# Let’s have a look at the simplest ones to start with:
# 1. int- integer values (whole numbers)
# 2. float- floating-point values (decimal numbers)
# 3. str- strings (sequence of characters like words & sentences)
# 4. bool- boolean values ( / )
# 5. none- special constant representing no value / null
# We also have a lot of other data types like complex, list, tuple , set etc. that we’ll
# cover in coming chapters. To check the variable type we can use type() function.

# %%
x = 10
print(type(x)) # <class 'int'>
PI = 3.14
print(type(PI)) # <class 'float'>
name = "Harjot Singh"
print(type(name)) # <class 'str'>
isTeacher = True

empty_var = None
print(type(empty_var)) # <class 'NoneType'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'NoneType'>

# %% [markdown]
# Type Conversion & Type Casting
# Type conversion is when we convert(cast) variables from one type to another. It can
# happen in 2 ways:
# 1. Type conversion - Implicit, done automatically by Python

# %%
a = 5
b = 3.0
print(a + b) # Python converts ans in float by default
# Out:
# 8.0

# %% [markdown]
# 2. Type Casting - Explicitly, done by the programmer

# %%
x = 10 # int
y = float(x) # convert to float
z = str(x) # convert to string

# %% [markdown]
# Operators
# An operator is a symbol that tells Python to perform a specific computation on one
# or more values (called operands).
# Example:

# %%
print(1 + 3) # '+' is an Operator & (1, 3) are operands
# Out:
# 4

# %% [markdown]
# There are several types of operators in Python. Let’s start by understanding some of
# the most common ones:
# 1. Arithmetic Operators - used to perform math operations.

# %%
a = 5
b = 10
print(a + b) # Addition
print(a - b) # Subtraction
print(a * b) # Multiplication
print(a / b) # Division
print(a % b) # Modulo - remainder
print(a ** b) # Power
# Out:
# 15
# -5
# 50
# 0.5
# 5
# 9765625

# %% [markdown]
# 2. Relational Operators - used to compare values.

# %%
a = 10
b = 20
# Equal to
print("a == b:", a == b) # False
# Not equal to
print("a != b:", a != b) # True
# Greater than
print("a > b:", a > b) # False
# Less than
print("a < b:", a < b) # True
# Greater than or equal to
print("a >= b:", a >= b) # False
# Less than or equal to
print ("a <= b:", a <= b) # True
# Out:
# a == b: False
# a != b: True
# a > b: False
# a < b: True
# a >= b: False
# a <= b: True

# %% [markdown]
# 3. Assignment Operators - used to assign values to variables.

# %%
# Simple assignment
x = 10
print("x =", x) # 10
x += 5 # equivalent to x = x + 5
print("x += 5 ->", x) # 15
x -= 3 # equivalent to x = x - 3
print("x -= 3 ->", x) # 12
x *= 2 # equivalent to x = x * 2
print("x *= 2 ->", x) # 24
x /= 4 # equivalent to x = x / 4
print("x /= 4 ->", x) # 6.0
x %= 4 # equivalent to x = x % 4
print("x %= 4 ->", x) # 2.0
x **= 3 # equivalent to x = x ** 3
print("x **= 3 ->", x) # 8.0
# Out:
# x = 10
# x += 5 -> 15
# x -= 3 -> 12
# x *= 2 -> 24
# x /= 4 -> 6.0
# x %= 4 -> 2.0
# x **= 3 -> 8.0

# %% [markdown]
# 4. Logical Operators - used to combine boolean values.

# %%
x = 10
y = 20
z = 5
# AND
print(x > z and y > x) # True
# OR
print(x > y or y > z) # True
# NOT
print(not (x > y)) # True
# Out:
# True
# True
# True

# %% [markdown]
# Operator Precendence
# Operators have a priority; it means there is a specific order in which operations are
# performed when we have multiple operators appearing in the same expression. The
# order is as follows:
# • ()- Parentheses (highest priority)
# • **- Exponent
# • +x, -x, ~x- Unary operators
# • *, /, //, %- Multiplication, division, floor, modulus
# • +, - - Addition, subtraction
# • << >>- Bitwise shifts
# • &- Bitwise AND
# • ^- Bitwise XOR
# • |- Bitwise OR
# • Comparison operators - <, <=, >, >=, !=, ==
# • not
# • and
# • or
# • Assignment operators -=, +=, -= ...

# %%
# Note - Unary operators are operators that works on a single operand
# (a single value or variable) to perform an operation. These are like ,
#  (unary plus), (unary minus) etc.
#  is used to indicate positive value & to indicate negative value.

x = 5
y = -x # unary minus
print(x) # 5
print(y) # -5
# Out:
# 5
# -5

# %%
# We use the function to take input from user while the program is running.
# Whatever the user types in input prompt is returned as a string.
name = input("Enter your name: ")
print(name)
print(type(name)) # type is string

#We can use type conversion functions to convert the type of input.
# program to add 2 numbers entered by the user
a = int(input("enter 1st num: "))
b = int(input("enter 2nd num: "))
print(a + b)

# Let’s summarize all the concepts we learnt in this chapter into a simple practice
# problem

a = int(input("enter 1st num: ")) # 5
b = int(input("enter 2nd num: ")) # 10
avg = (a + b) / 2
print("average = ", avg) # 7.5
# Out:
# Harjot
# <class 'str'>
# 33
# average =  16.5
